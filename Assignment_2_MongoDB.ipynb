# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhu98765/assignmment_2/blob/main/Assignment_2_MongoDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pymongo import MongoClient
madhu=MongoClient("mongodb://madhu213:madhu213@ac-pahu2uk-shard-00-00.n8xouvb.mongodb.net:27017,ac-pahu2uk-shard-00-01.n8xouvb.mongodb.net:27017,ac-pahu2uk-shard-00-02.n8xouvb.mongodb.net:27017/?ssl=true&replicaSet=atlas-cktchf-shard-0&authSource=admin&retryWrites=true&w=majority")
m1=madhu["sample_mflix"]
movie=m1["movies"]
for i in movie.find({"$and":[{"$or":[{"year":{"$gt":1950,"$lt":1970}},{"year":{"$gt":2000,"$lt":2015}}]},{"$or":[{"genres":"Comedy"},{"genres":"Horror"},{"genres":"Fantasy"}]},{"tomatoes.viewer.rating":{"$gte":3}},{"imdb.rating":{"$gt":7}},{"awards.wins":{"$gte":1}}]},{"_id":0,"title":1,"directors":1,"cast":1,"tomatoes.viewer.rating":1,"imdb.rating":1}):
  print(i)
# Out:
# {'cast': ['Fernandel', 'Gino Cervi', 'Vera Talchi', 'Franco Interlenghi'], 'title': 'The Little World of Don Camillo', 'directors': ['Julien Duvivier'], 'imdb': {'rating': 7.8}, 'tomatoes': {'viewer': {'rating': 3.9}}}
# {'cast': ['Gene Tierney', 'John Lund', 'Miriam Hopkins', 'Thelma Ritter'], 'title': 'The Mating Season', 'directors': ['Mitchell Leisen'], 'imdb': {'rating': 7.6}, 'tomatoes': {'viewer': {'rating': 4.5}}}
# {'cast': ['Moira Shearer', 'Ludmilla Tchèrina', 'Ann Ayars', 'Pamela Brown'], 'title': 'The Tales of Hoffmann', 'directors': ['Michael Powell', 'Emeric Pressburger'], 'imdb': {'rating': 7.4}, 'tomatoes': {'viewer': {'rating': 3.8}}}
# {'cast': ['Alec Guinness', 'Stanley Holloway', 'Sidney James', 'Alfie Bass'], 'title': 'The Lavender Hill Mob', 'directors': ['Charles Crichton'], 'imdb': {'rating': 7.8}, 'tomatoes': {'viewer': {'rating': 3.9}}}
# ...
